# %%
import pandas as pd
data=pd.read_csv("C:\\Users\\Hello\\Downloads\\insurance.csv")
data
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use("Solarize_Light2")
plt.title("Age-Bmi")
plt.plot(data['age'],data['bmi'])
plt.xlabel("x axis",fontsize=18,loc='center')
plt.ylabel("y axis",fontsize=18,loc='center')
plt.show()

# %%
data=pd.read_csv("C:\\Users\\Hello\\Downloads\\movie_dataset.csv\\movie_dataset.csv")
data
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
s=data.head(10)
s
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
# 5      5  258000000                  Fantasy Action Adventure
# 6      6  260000000                          Animation Family
# 7      7  280000000          Action Adventure Science Fiction
# 8      8  250000000                  Adventure Fantasy Family
# 9      9  250000000                  Action Adventure Fantasy
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
plt.style.use("Solarize_Light2")
plt.title("Vote_Average - Runtime",color="Green")
plt.xlabel("Vote_Average",fontsize='18',loc="center",color="red")
plt.ylabel("Runtime",fontsize='18',loc="center",color="red")
plt.plot(s['vote_average'],s['runtime'])
plt.show()

# %%
import pandas as pd
data=pd.read_csv("C:\\Users\\Hello\\Downloads\\50_Startups.csv")
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
s=data.head(10)
s
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12
# 6  134615.46       147198.87        127716.82  California  156122.51
# 7  130298.13       145530.06        323876.68     Florida  155752.60
# 8  120542.52       148718.95        311613.29    New York  152211.77
# 9  123334.88       108679.17        304981.62  California  149759.96

# %%
import matplotlib.pyplot as plt
plt.style.use("Solarize_Light2")
plt.title("R&D Spend-Administration",color="Green")
plt.xlabel("R&D spend",fontsize='18',loc="center",color="red")
plt.ylabel("Administration",fontsize='18',loc="center",color="red")
plt.plot(data['R&D Spend'],data['Administration'])
plt.show()

# %%
# plt.figure(figsize=(50,80),facecolor='lightblue',edgecolor='pink',linewidth=5)
x=s['R&D Spend']
y=s["Administration"]
plt.xlabel("R&D Spend",fontsize='25')
plt.ylabel("Administration")
plt.subplot(2,1,1)
plt.plot(x,y)
#plt.xticks(np.arange(120000,160000,100000))
#plt.yticks(np.arange(100000,1400000,20000))
x=s["Administration"]
y=s["Profit"]
plt.xlabel("Administartion")
plt.ylabel("Profit")
plt.subplot(2,1,2)
plt.plot(x,y)
#plt.xticks(np.arange(90000,150000,100000))
#plt.yticks(np.arange(150000,1900000,100000))
plt.show()
