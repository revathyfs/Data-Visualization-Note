# %% [markdown]
# Numpy

# %% [markdown]
# 💡 What is NumPy?
#
# NumPy (Numerical Python) is a library for working with arrays. It supports large, multi-dimensional arrays and matrices, along with a collection of high-level mathematical functions.
#
# ✨ Key Concepts
#
# - ndarray: Core data structure
#
# - Broadcasting
#
# - Vectorized operations

# %%
# importing

import numpy as np

# %%
# Create array
a = np.array([1, 2, 3])
b = np.array([[1, 2], [3, 4]])

# %%
# Shape and type
print(a.shape)       
print(b.dtype)
# Out:
# (3,)
# int64

# %%
# Array of zeros/ones
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((3,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
# Range
np.arange(0,10,2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
# Reshape
a = np.arange(6).reshape((2, 3))

# %%
a
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
# Math operations
w=a + 1
np.mean(w)
# Out:
# np.float64(3.5)

# %%
# Indexing & Slicing

a = np.array([10, 20, 30, 40])
print(a[1:3])
# Out:
# [20 30]

# %% [markdown]
# Pandas

# %% [markdown]
# 💡 What is Pandas?
#
# Pandas provides powerful data structures for data manipulation and analysis: Series and DataFrame.

# %%
#Importing

import pandas as pd

# %%
# Series
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
# DataFrame
data = {'Name': ['Alice', 'Bob'], 'Age': [25, 30]}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
# Read CSV
#df = pd.read_csv("C:\\Users\\Hello\\Downloads\\War.csv")

# %%
#df

# %%
# View data
df.head()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.tail()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      object
#  1   Age     2 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 164.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   27.500000
# std     3.535534
# min    25.000000
# 25%    26.250000
# 50%    27.500000
# 75%    28.750000
# max    30.000000

# %%
# Basic Operations

df['Age']        # Access column
df.iloc[0]       # Access row by index
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
df.loc[0, 'Name'] # Row and column
# Out:
# 'Alice'

# %%
df['Age'] > 26   # Filtering condition
# Out:
# 0    False
# 1     True
# Name: Age, dtype: bool

# %%
df[df['Age'] > 26]
# Out:
#   Name  Age
# 1  Bob   30

# %%
# Handling Missing Data

df.dropna()       # Remove NaNs
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.fillna(0)      # Replace NaNs
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %% [markdown]
# Matplotlib

# %% [markdown]
# 💡 What is Matplotlib?
#
# Matplotlib is a plotting library for creating static, animated, and interactive visualizations in Python.

# %%
# Importing
import matplotlib.pyplot as plt

# %%
#Plotting

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.title("Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# Other Plot Types

# %%
# Bar plot
plt.bar(['A', 'B', 'C'], [3, 7, 1])
plt.show()

# %%
# Histogram
data = [1, 2, 2, 3, 3, 3, 4]
plt.hist(data, bins=4)
plt.show()

# %%
# Scatter plot
plt.scatter(x, y)
plt.show()

# %%
# Pie chart
labels = ['A', 'B', 'C']
sizes = [15, 30, 55]
plt.pie(sizes, labels=labels, autopct='%1.1f%%')

plt.show()

# %% [markdown]
# Seaborn

# %% [markdown]
# 💡 What is Seaborn?
#
# Seaborn is built on top of Matplotlib and provides a high-level interface for attractive statistical graphics.

# %%
# Importing

import seaborn as sns

# %%
# shows in-build dataset
dataset_names = sns.get_dataset_names()
print(dataset_names)
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
# Dataset & Plots

# Built-in dataset
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Scatter plot with regression line
sns.lmplot(x="total_bill", y="tip", data=df)
plt.show()

# %%
# Box plot
sns.boxplot(x="day", y="total_bill", data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Count plot
sns.countplot(x="day", data=df)
plt.show()

# %%
# Histogram / KDE
sns.histplot(df['total_bill'], kde=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Heatmap (correlation)
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
# NumPy 
#Use the tips dataset to extract numeric array operations:

import numpy as np
import seaborn as sns

tips = sns.load_dataset('tips')
print(tips.head())

# Convert numeric columns to NumPy array
num_cols = tips[['total_bill', 'tip']]
arr = num_cols.to_numpy()

print(arr.shape)  
print("Mean total bill:", np.mean(arr[:,0]))
print("Tip std dev:", np.std(arr[:,1]))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# (244, 2)
# Mean total bill: 19.78594262295082
# Tip std dev: 1.3807999538298954

# %% [markdown]
# Explore:
#
# - Reshaping: arr.reshape(-1,)
#
# - Broadcasting: adding a constant
#
# - Filtering: arr[arr[:,1] > np.mean(arr[:,1])]

# %%
#Pandas
#Use DataFrame power to analyze the dataset:

import pandas as pd

df = tips.copy()
df.info()
df.describe()

# New column: tip percentage
df['tip_pct'] = df['tip'] / df['total_bill'] * 100

# Filter big bills
big_bills = df[df['total_bill'] > 20]
print(big_bills[['total_bill', 'tip_pct']].head())

# Group and aggregate
grouped = df.groupby('day')['tip_pct'].agg(['mean', 'count'])
print(grouped)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
#    total_bill    tip_pct
# 2       21.01  16.658734
# 3       23.68  13.978041
# 4       24.59  14.680765
# 5       25.29  18.623962
# 7       26.88  11.607143
#            mean  count
# day
# Thur  16.127563     62
# Fri   16.991303     19
# Sat   15.315172     87
# Sun   16.689729     76
# ...

# %%
#Matplotlib
#Plot from scratch with Matplotlib:

import matplotlib.pyplot as plt

# Scatter: total bill vs tip percentage
plt.figure(figsize=(6, 4))
plt.scatter(df['total_bill'], df['tip_pct'], alpha=0.6)
plt.title("Tip % vs Total Bill")
plt.xlabel("Total Bill ($)")
plt.ylabel("Tip (%)")
plt.grid(True)
plt.show()

# %%
#  Seaborn
# Create polished visuals with Seaborn:

import seaborn as sns

# Load data with tip_pct
df = sns.load_dataset('tips')
df['tip_pct'] = df['tip'] / df['total_bill'] * 100

# lmplot
sns.lmplot(x='total_bill', y='tip_pct', hue='day', data=df, height=5)
plt.title("Tip% vs Bill by Day")

# Boxplot
plt.figure(figsize=(6,4))
sns.boxplot(x='day', y='tip_pct', data=df)
plt.title("Tip % Distribution by Day")

# Heatmap of correlations
corr = df[['total_bill', 'tip', 'tip_pct', 'size']].corr()
plt.figure(figsize=(5,4))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()
