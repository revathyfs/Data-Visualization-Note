# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset('iris')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data.shape
# Out:
# (150, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 data.corr()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
#    2000     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
data.select_dtypes(include='number').corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0,1, 1,2, 2,2,2,3,4,4,4,4,5])
plt.show()
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_14172\3366410811.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1, 1,2, 2,2,2,3,4,4,4,4,5])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#kernel density estimate (KDE) 
sns.distplot([0,1,2,3,4,5], hist=False)

plt.show()
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_14172\1349637555.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5], hist=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot([0,1, 1,2, 2,2,2,3,4,4,4,4,5],discrete=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot([0,1,2,3],discrete=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0,1,2,3,4,5], kde=False)

plt.show()
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_14172\1986425220.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5], kde=False)

# %% [markdown]
# Draw the heat mp to show the intensity of corr

# %%
data = sns.load_dataset('iris')
sns.heatmap(data.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 2
#       1 data = sns.load_dataset('iris')
# ----> 2 sns.heatmap(data.corr(),annot=True)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
# ...

# %%
data = sns.load_dataset('iris')

# Select only numeric columns for correlation
numeric_data = data.select_dtypes(include='number')

# Plot the heatmap
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of Iris Dataset")
plt.show()

# %%
sns.heatmap(data.corr(),annot=True,linewidth=4,cmap='gnuplot',linecolor='k')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 sns.heatmap(data.corr(),annot=True,linewidth=4,cmap='gnuplot',linecolor='k')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
# ...

# %%
# Load dataset
data = sns.load_dataset('iris')

# Select numeric columns only
numeric_data = data.select_dtypes(include='number')

# Plot the heatmap with your desired settings
sns.heatmap(numeric_data.corr(), 
            annot=True, 
            linewidth=4, 
            cmap='gnuplot', 
            linecolor='k')

plt.title("Correlation Heatmap of Iris Numeric Features")
plt.show()

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
sns.heatmap(data.isnull(),annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
data=pd.DataFrame({
    'A':[1,2,None,4],
    'B':[None,2,3,4],
    'C':[1,None,3,None]
})
sns.heatmap(data.isnull(),annot=True,cbar=True)
# Out:
# <Axes: >

# %%
sns.heatmap(data.corr(),annot=True,linewidth=4,cmap='gnuplot',linecolor='k')
# Out:
# <Axes: >

# %%
# run after " data.isnull().sum() & sns.heatmap(data.isnull(),annot=True)"


sns.distplot(data['sepal_length'])
plt.show()
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_14172\1014705409.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['sepal_length'])

# %%
sns.distplot(data['sepal_length'],kde=False) #kernel density estimation
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_14172\245640172.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['sepal_length'],kde=False) #kernel density estimation
# <Axes: xlabel='sepal_length'>

# %%
sns.distplot(data['sepal_length'],hist=False)
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_14172\4126301961.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['sepal_length'],hist=False)
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# Joint plot

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=data,kind='hex',dropna=True)
#sns.jointplot(x='sepal_length', y='sepal_width', data=data, kind='hex', dropna=True, color='blue', gridsize=30)

# %%
sns.jointplot(x="sepal_length",y='sepal_width',data=data,kind='reg',dropna=True)

# %%
sns.jointplot(x="sepal_length",y='sepal_width',data=data,kind='resid',dropna=True)

# %%
sns.jointplot(x="sepal_length",y='sepal_width',data=data,kind='kde',dropna=True)

# %%
sns.jointplot(x="sepal_length",y='sepal_width',data=data,dropna=True,
             height=10,ratio=4,marker="*",marginal_kws=dict(bins=20,fill=True))

# %%
sns.pairplot(data,diag_kind='kde',hue='species')

# %%
sns.stripplot(x='species',y='petal_length',jitter=False,data=data)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %% [markdown]
# Stripple plot

# %%
sns.stripplot(x='species',y='petal_length',jitter=True,data=data)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.stripplot(x='species',y='petal_length',jitter=True,data=data)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %% [markdown]
# Swarmplot

# %%
sns.swarmplot(x='species',y='petal_length',data=data)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Box Plot

# %%
sns.boxplot(x='species',y='petal_length',data=data)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(x='species',y='petal_length',data=data,fliersize=12,palette='seismic')
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_14172\366086479.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species',y='petal_length',data=data,fliersize=12,palette='seismic')
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(data=data,fliersize=12,palette='flag',orient='h')
# Out:
# <Axes: >

# %% [markdown]
# violin plot-combination of boxplot and kde plot

# %%
sns.violinplot(data=data,palette='pink',orient='v')
# Out:
# <Axes: >

# %%
sns.violinplot(data=data, palette='pink', orient='v', inner='box', linewidth=1.5)
# Out:
# <Axes: >

# %%
sns.violinplot(data=data,palette='gist_heat_r',inner='quartiles',x='species',y='petal_length',hue='species')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
# correct code
sns.violinplot(data=data, palette='gist_heat_r', inner='quartile', x='species', y='petal_length', hue='species')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.violinplot(data=data,palette='gist_heat_r',x='species',y='petal_length',inner='stick',hue='species')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.violinplot(
    data=data,
    palette='gist_heat_r',
    x='species',
    y='petal_length',
    inner='stick',    # shows individual observations as sticks
    hue='species'
)

plt.show()

# %% [markdown]
# Bar Plot

# %%
sns.barplot(x='species',y='petal_length',data=data)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %% [markdown]
# COUNT PLOT

# %%
sns.countplot(x='species',data=data)
# Out:
# <Axes: xlabel='species', ylabel='count'>
